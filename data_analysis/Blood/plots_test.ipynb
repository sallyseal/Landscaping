# %%
# Pkg.add("StatPlots")
using StatPlots # Required for the DataFrame user recipe
# Now let's create the DataFrame
using DataFrames
df = DataFrame(a = 1:10, b = 10*rand(10), c = 10 * rand(10))
# Plot the DataFrame by declaring the points by the column names
@df df plot(:a, [:b :c]) # x = :a, y = [:b :c]. Notice this is two columns!

# %%
# Initialize the functions necessary for this script
using DataFrames;
using Plots;
using StatPlots;

# Read in the transformed csv containing the data
# Read in the csv containing the pairs of genes and mi measures which is sorted
df1 = readtable("combined_no_HK_T.csv")
df2 = readtable("mi_no_HK_sorted_v3.csv")

# Create a new dataframe which is a slice from df2 of the pairs of genes to analyse
# df3 contains first 10 rows and we can modify this to grab the genes we want
df3 = df2[1:3,1:3]

# Initialize the variables
# gene1 = []
# gene2 = []

# Iterate through the df and pull out first and second column and push to gene1 and gene2
for i in eachrow(df3)
    gene_1 = i[1]
    gene_2 = i[2]
#     push!(gene1, i[1])
#     push!(gene2, i[2])
    println(gene_1)
    println(gene_2)
    
    plot = @df df1 scatter(:gene_1, :gene_2)
    display(plot)
end

# Iterate through the df and pull out first and second column and push to gene1 and gene2
# for i in eachrow(df3)
#     gene_1 = i[1]
#     gene_2 = i[2]
# #     push!(gene1, i[1])
# #     push!(gene2, i[2])
#     println(gene_1)
#     println(gene_2)
#     gene_1 = convert(Symbol,gene_1)
#     gene_2 = convert(Symbol,gene_2)

#     plot = @df df1 scatter([Symbol("gene_1"), Symbol("gene_2")])
#     display(plot)
# end 
# println(df3)
# println(gene1)
# println(gene2)


# Iterate through df1 and check if column 1 == gene1[1] && column 2 == gene2[1]
# If true then extract the values associated with each gene and plot them


    # Define the plotting function
# function plotting(df)

    # Look in the MI csv (df2) to see the names of pairs of genes to be plotted
    # Arrange to select numbers of pairs e.g. top 10 (2:11)
#     for i in eachrow(df2)
#         println(i[1])
#     end

    # Then get the data points of these genes in the df1
    # Define plots to call later as sub-plots
#     p = @df scatter(:RUNX1, :TGFB1)
#     # p2 = @df scatter(:ANK1, :GATA1)

#     # Define the plot as variable p to call later
#     # p = plot(p1, p2, layout=(1,1), legend=false)

#     # Display the plot
#     display(p)
#     # savefig(p, "myplot.png")
# Out:
# CD41/ITGA2B
# GATA1
# WARNING: readtable is deprecated, use CSV.read from the CSV package instead
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] #readtable#229(::Bool, ::Char, ::Array{Char,1}, ::Char, ::Array{String,1}, ::Array{String,1}, ::Array{String,1}, ::Bool, ::Int64, ::Array{Symbol,1}, ::Array{Any,1}, ::Bool, ::Char, ::Bool, ::Int64, ::Array{Int64,1}, ::Bool, ::Symbol, ::Bool, ::Bool, ::DataFrames.#readtable, ::String) at /home/megan/.julia/v0.6/DataFrames/src/deprecated.jl:1045
#  [3] readtable(::String) at /home/megan/.julia/v0.6/DataFrames/src/deprecated.jl:1045
#  [4] include_string(::String, ::String) at ./loading.jl:522
#  [5] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /home/megan/.julia/v0.6/IJulia/src/execute_request.jl:158
#  [6] (::Compat.#inner#17{Array{Any,1},IJulia.#execute_request,Tuple{ZMQ.Socket,IJulia.Msg}})() at /home/megan/.julia/v0.6/Compat/src/Compat.jl:385
# ...
