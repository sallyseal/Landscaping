# %%
import pandas as pd
import numpy as np

# %%
# This code cleans the 3 patient datasets to exclude the empty lines between each gene and writes them to a file called original name_cleaned
# REMEMBER P1expr.csv is a TAB seperated file sep = '\t'

# %%
df1 = pd.read_csv('P1expr.csv', sep = '\t')

# %%
df1.head()
# Out:
#   Gene ID  A1P1MEP-A1_a1p1  A1P1MEP-A10_a1p1  A1P1MEP-A11_a1p1  \
# 0     NaN              NaN               NaN               NaN
# 1    ADD2              0.0               0.0               0.0
# 2     NaN              NaN               NaN               NaN
# 3    ANK1              0.0               0.0               0.0
# 4     NaN              NaN               NaN               NaN
#
#    A1P1MEP-A12_a1p1  A1P1MEP-A2_a1p1  A1P1MEP-A3_a1p1  A1P1MEP-A4_a1p1  \
# 0               NaN              NaN              NaN              NaN
# 1               0.0              0.0              0.0              0.0
# 2               NaN              NaN              NaN              NaN
# 3               0.0              0.0              0.0              0.0
# 4               NaN              NaN              NaN              NaN
#
#    A1P1MEP-A5_a1p1  A1P1MEP-A9_a1p1       ...         A3P1MEP-H11_a3p1  \
# 0              NaN              NaN       ...                      NaN
# ...

# %%
df1.shape
# Out:
# (180, 286)

# %%
df1_cleaned = df1.dropna(how='all')

# %%
df1_cleaned.shape
# Out:
# (90, 286)

# %%
df1_cleaned.head()
# Out:
#     Gene ID  A1P1MEP-A1_a1p1  A1P1MEP-A10_a1p1  A1P1MEP-A11_a1p1  \
# 1      ADD2         0.000000          0.000000          0.000000
# 3      ANK1         0.000000          0.000000          0.000000
# 5       B2M        16.254905         15.125025         21.628053
# 7      BDH1         0.000000         21.681560          0.000000
# 9  BIM/BCL2         0.000000         24.374786          0.000000
#
#    A1P1MEP-A12_a1p1  A1P1MEP-A2_a1p1  A1P1MEP-A3_a1p1  A1P1MEP-A4_a1p1  \
# 1          0.000000         0.000000         0.000000         0.000000
# 3          0.000000         0.000000         0.000000         0.000000
# 5         22.309525        12.696938        11.498852        12.343423
# 7          0.000000         0.000000         0.000000         0.000000
# 9          0.000000         0.000000         0.000000         0.000000
#
#    A1P1MEP-A5_a1p1  A1P1MEP-A9_a1p1       ...         A3P1MEP-H11_a3p1  \
# 1         0.000000         0.000000       ...                      0.0
# ...

# %%
df2 = pd.read_csv('P2expr.csv')

# %%
df2.head()
# Out:
#   Gene ID  A1P2MEP-A1_a1p2  A1P2MEP-A10_a1p2  A1P2MEP-A11_a1p2  \
# 0     NaN              NaN               NaN               NaN
# 1    ADD2              NaN               NaN               NaN
# 2     NaN              NaN               NaN               NaN
# 3    ANK1              NaN         15.742857               NaN
# 4     NaN              NaN               NaN               NaN
#
#    A1P2MEP-A12_a1p2  A1P2MEP-A2_a1p2  A1P2MEP-A3_a1p2  A1P2MEP-A4_a1p2  \
# 0               NaN              NaN              NaN              NaN
# 1               NaN              NaN              NaN              NaN
# 2               NaN              NaN              NaN              NaN
# 3               NaN        15.719132              NaN              NaN
# 4               NaN              NaN              NaN              NaN
#
#    A1P2MEP-A5_a1p2  A1P2MEP-A6_a1p2       ...         A3P2MEP-H11_a3p2  \
# 0              NaN              NaN       ...                      NaN
# ...

# %%
df2.shape
# Out:
# (180, 289)

# %%
df2_cleaned = df2.dropna(how='all')

# %%
df2_cleaned.head()
# Out:
#     Gene ID  A1P2MEP-A1_a1p2  A1P2MEP-A10_a1p2  A1P2MEP-A11_a1p2  \
# 1      ADD2              NaN               NaN               NaN
# 3      ANK1              NaN         15.742857               NaN
# 5       B2M        13.503677         12.180925               NaN
# 7      BDH1              NaN               NaN               NaN
# 9  BIM/BCL2              NaN         21.319226               NaN
#
#    A1P2MEP-A12_a1p2  A1P2MEP-A2_a1p2  A1P2MEP-A3_a1p2  A1P2MEP-A4_a1p2  \
# 1               NaN              NaN              NaN              NaN
# 3               NaN        15.719132              NaN              NaN
# 5         13.511578        11.938799        12.974708              NaN
# 7               NaN        19.017497              NaN              NaN
# 9               NaN        20.422011              NaN        21.460935
#
#    A1P2MEP-A5_a1p2  A1P2MEP-A6_a1p2       ...         A3P2MEP-H11_a3p2  \
# 1              NaN              NaN       ...                      NaN
# ...

# %%
df3 = pd.read_csv('P3expr.csv')

# %%
df3.head()
# Out:
#   Gene ID  A1P3-7141-A1_a1p3  A1P3-7141-A10_a1p3  A1P3-7141-A11_a1p3  \
# 0     NaN                NaN                 NaN                 NaN
# 1    ADD2                NaN                 NaN                 NaN
# 2     NaN                NaN                 NaN                 NaN
# 3    ANK1          15.094331           22.426016           16.262384
# 4     NaN                NaN                 NaN                 NaN
#
#    A1P3-7141-A12_a1p3  A1P3-7141-A2_a1p3  A1P3-7141-A3_a1p3  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN          12.478567          16.128982
# 4                 NaN                NaN                NaN
#
#    A1P3-7141-A4_a1p3  A1P3-7141-A5_a1p3  A1P3-7141-A6_a1p3       ...        \
# 0                NaN                NaN                NaN       ...
# ...

# %%
df3.shape
# Out:
# (180, 235)

# %%
df3_cleaned = df3.dropna(how='all')

# %%
df3_cleaned.head()
# Out:
#     Gene ID  A1P3-7141-A1_a1p3  A1P3-7141-A10_a1p3  A1P3-7141-A11_a1p3  \
# 1      ADD2                NaN                 NaN                 NaN
# 3      ANK1          15.094331           22.426016           16.262384
# 5       B2M           9.521889           10.039254           10.828808
# 7      BDH1          17.341750                 NaN                 NaN
# 9  BIM/BCL2          18.704411           21.353992           19.142622
#
#    A1P3-7141-A12_a1p3  A1P3-7141-A2_a1p3  A1P3-7141-A3_a1p3  \
# 1                 NaN                NaN                NaN
# 3                 NaN          12.478567          16.128982
# 5           15.736447           9.408218           9.900805
# 7                 NaN          17.335573          17.353531
# 9           19.070839                NaN                NaN
#
#    A1P3-7141-A4_a1p3  A1P3-7141-A5_a1p3  A1P3-7141-A6_a1p3       ...        \
# 1                NaN                NaN                NaN       ...
# ...

# %%
df1_cleaned.to_csv('P1expr_cleaned.csv', sep = '\t')
df2_cleaned.to_csv('P2expr_cleaned.csv')
df3_cleaned.to_csv('P3expr_cleaned.csv')
